# %%
import pandas as pd

# %%
df = pd.read_csv("db/tweet/HSpam_dataset1.csv")
df
# Out:
#       id                                              tweet  no_followers  \
# 0      2              That just seriously ruined my night..           163
# 1      3  @JessleaC I no they are so funny ..! I love yo...           113
# 2      5  @honkwas might drive so we could go subway or ...           168
# 3      9  That @brad_frost post is bourne out by my expe...           285
# 4     10       why tf do i keep waking up every 2 hours -.-           631
# ..   ...                                                ...           ...
# 98   190  If I wanted to read your convo I would click o...           252
# 99   192  @OMGFacts I find a decent pair of #Jockeys wil...            75
# 100  193  hmm stupid ass alarm got me liking country music.           502
# 101  195  _/|\_ YOU  yourself, as much as anybody in the...          1433
# 102  196  What keeps me busy on a thursday afternoon 💅 #...          1733
#
#      no_followings  no_userfavorites  no_lists  no_tweets  no_retweets  \
# ...
